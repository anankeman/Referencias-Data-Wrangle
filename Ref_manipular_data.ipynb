# %% [markdown]
# # Manipular datos con pandas

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import scipy.stats as stats

# %% [markdown]
# ## Cagar y limpiar data

# %%
data = pd.read_csv("C:/Users/Cami/Google Drive/Python/noticias/bbnoticias.csv",
                   encoding="utf-8", sep=",", parse_dates=['date'], dayfirst=True, index_col='date')

# %%
data.dropna(inplace=True)

# %%
data.drop_duplicates(['href-href'], inplace=True)

# %% [markdown]
# ### Cargar SQL

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql://root:00mayaman@localhost/hausapp")

df=pd.read_sql_table("gumtree",engine)
df
# Out:
# Empty DataFrame
# Columns: [address, availability, bathroom, bedrooms, date_listed, date_update, furnished, gender, link, parking, pet, price, smoking, text, title, type_, user, views]
# Index: []

# %%
df.to_sql(
    name='customers', # database table name
    con=engine,
    if_exists='append',
    index=False
)

# %% [markdown]
# ## Seleccionar y filtrar

# %% [markdown]
# ## Por nombre columna

# %%
data.cat[:3]
# Out:
# date
# 2017-10-16 17:52:00    noticias/internacional
# 2017-10-24 21:08:00         noticias/nacional
# 2017-10-13 12:26:00         noticias/economia
# Name: cat, dtype: object

# %%
data["cat"][:3]
# Out:
# date
# 2017-10-16 17:52:00    noticias/internacional
# 2017-10-24 21:08:00         noticias/nacional
# 2017-10-13 12:26:00         noticias/economia
# Name: cat, dtype: object

# %%
data[["cat","visitas"]][:3]
# Out:
#                                         cat  visitas
# date
# 2017-10-16 17:52:00  noticias/internacional    515.0
# 2017-10-24 21:08:00       noticias/nacional   4713.0
# 2017-10-13 12:26:00       noticias/economia  18073.0

# %% [markdown]
# ## Por indice

# %%
data.iloc[:3]
# Out:
#                                                                   href  \
# date
# 2017-10-16 17:52:00  16/10/2017 17:52\n            Corea del Norte ...
# 2017-10-24 21:08:00  24/10/2017 21:08\n            Corte de Concepc...
# 2017-10-13 12:26:00  13/10/2017 12:26\n            Emiten alerta de...
#
#                                                              href-href  \
# date
# 2017-10-16 17:52:00  http://www.biobiochile.cl/noticias/internacion...
# 2017-10-24 21:08:00  http://www.biobiochile.cl/noticias/nacional/re...
# 2017-10-13 12:26:00  http://www.biobiochile.cl/noticias/economia/tu...
#
#                      visitas  \
# date
# 2017-10-16 17:52:00    515.0
# 2017-10-24 21:08:00   4713.0
# 2017-10-13 12:26:00  18073.0
#
#                                                                  tagas  \
# date
# 2017-10-16 17:52:00  #Corea del Norte#Donald Trump#Kim Jong-Un#prog...
# 2017-10-24 21:08:00  #Concepción#Emilio Berkhoff#libertad condicion...
# ...

# %%
data[:3]
# Out:
#                                                                   href  \
# date
# 2017-10-16 17:52:00  16/10/2017 17:52\n            Corea del Norte ...
# 2017-10-24 21:08:00  24/10/2017 21:08\n            Corte de Concepc...
# 2017-10-13 12:26:00  13/10/2017 12:26\n            Emiten alerta de...
#
#                                                              href-href  \
# date
# 2017-10-16 17:52:00  http://www.biobiochile.cl/noticias/internacion...
# 2017-10-24 21:08:00  http://www.biobiochile.cl/noticias/nacional/re...
# 2017-10-13 12:26:00  http://www.biobiochile.cl/noticias/economia/tu...
#
#                      visitas  \
# date
# 2017-10-16 17:52:00    515.0
# 2017-10-24 21:08:00   4713.0
# 2017-10-13 12:26:00  18073.0
#
#                                                                  tagas  \
# date
# 2017-10-16 17:52:00  #Corea del Norte#Donald Trump#Kim Jong-Un#prog...
# 2017-10-24 21:08:00  #Concepción#Emilio Berkhoff#libertad condicion...
# ...

# %%
data.iloc[:3,:2]
# Out:
#                                                                   href  \
# date
# 2017-10-16 17:52:00  16/10/2017 17:52\n            Corea del Norte ...
# 2017-10-24 21:08:00  24/10/2017 21:08\n            Corte de Concepc...
# 2017-10-13 12:26:00  13/10/2017 12:26\n            Emiten alerta de...
#
#                                                              href-href
# date
# 2017-10-16 17:52:00  http://www.biobiochile.cl/noticias/internacion...
# 2017-10-24 21:08:00  http://www.biobiochile.cl/noticias/nacional/re...
# 2017-10-13 12:26:00  http://www.biobiochile.cl/noticias/economia/tu...

# %% [markdown]
# ## Por condición

# %%
data[data.visitas > 250000]
# Out:
#                                                                   href  \
# date
# 2017-10-11 21:55:00  11/10/2017 21:55\n            ANFP no denuncia...
# 2017-10-28 08:42:00  28/10/2017 08:42\n            Revisa si fuiste...
# 2017-10-06 08:44:00  06/10/2017 08:44\n            #EntregaBrasil: ...
# 2017-09-28 12:37:00  28/09/2017 12:37\n            "Tía... a mí me ...
#
#                                                              href-href  \
# date
# 2017-10-11 21:55:00  http://www.biobiochile.cl/noticias/deportes/fu...
# 2017-10-28 08:42:00  http://www.biobiochile.cl/noticias/nacional/ch...
# 2017-10-06 08:44:00  http://www.biobiochile.cl/noticias/deportes/fu...
# 2017-09-28 12:37:00  http://www.biobiochile.cl/noticias/opinion/tu-...
#
#                       visitas  \
# date
# 2017-10-11 21:55:00  256796.0
# 2017-10-28 08:42:00  323240.0
# 2017-10-06 08:44:00  263956.0
# 2017-09-28 12:37:00  287665.0
#
# ...

# %% [markdown]
# ## Por contenido

# %%
data[data.titulo.str.contains("SENAME")]
# Out:
#                                                                   href  \
# date
# 2017-09-17 08:45:00  17/09/2017 08:45\n            Dónde estará mej...
#
#                                                              href-href  \
# date
# 2017-09-17 08:45:00  http://www.biobiochile.cl/noticias/artes-y-cul...
#
#                      visitas                                      tagas  \
# date
# 2017-09-17 08:45:00   2172.0  #aborto#homosexuales#Menores#niños#Sename
#
#                                                                 titulo  \
# date
# 2017-09-17 08:45:00  Dónde estará mejor un niño: ¿Con una pareja ho...
#
#                                           cat
# date
# 2017-09-17 08:45:00  noticias/artes-y-cultura

# %% [markdown]
# # Resumir y agrupar data

# %%
data.cat.value_counts()
# Out:
# noticias/nacional                5079
# noticias/deportes                1548
# noticias/internacional            803
# noticias/espectaculos-y-tv        640
# noticias/sociedad                 375
# noticias/artes-y-cultura          372
# noticias/economia                 224
# noticias/bbtv                     219
# noticias/ciencia-y-tecnologia     199
# noticias/mujer                    169
# noticias/opinion                  133
# noticias/se-dijo-en-la-radio      116
# noticias/futbol-internacional      18
# noticias/hombre                    18
# noticias/biobiochile               10
# noticias/blogs                      9
# especial/noticias                   7
# Name: cat, dtype: int64

# %%
data.shape
# Out:
# (9939, 7)

# %%
data.describe()
# Out:
#              visitas
# count    9590.000000
# mean     7248.025860
# std     17592.481414
# min        58.000000
# 25%       444.000000
# 50%      1347.000000
# 75%      5442.500000
# max    323240.000000

# %%
data[['visitas','cat']].groupby('cat').mean()
# Out:
#                                     visitas
# cat
# especial/noticias                       NaN
# noticias/artes-y-cultura        2071.493333
# noticias/bbtv                           NaN
# noticias/biobiochile            6002.000000
# noticias/blogs                 13110.555556
# noticias/ciencia-y-tecnologia  12619.745000
# noticias/deportes               9793.327008
# noticias/economia               7820.553571
# noticias/espectaculos-y-tv     21351.501818
# noticias/futbol-internacional  10083.900000
# noticias/hombre                22850.055556
# noticias/internacional          4905.019254
# noticias/mujer                          NaN
# noticias/nacional               4425.708317
# noticias/opinion                5048.208955
# noticias/se-dijo-en-la-radio     482.879310
# noticias/sociedad              24855.051136

# %%
data.cat.unique()
# Out:
# array([u'noticias/internacional', u'noticias/nacional',
#        u'noticias/economia', u'noticias/deportes', u'noticias/sociedad',
#        u'noticias/artes-y-cultura', u'noticias/ciencia-y-tecnologia',
#        u'noticias/espectaculos-y-tv', u'noticias/opinion',
#        u'noticias/hombre', u'noticias/biobiochile',
#        u'noticias/futbol-internacional', u'noticias/blogs'], dtype=object)

# %% [markdown]
# ### Buscar palabras y contexto

# %%
data.titulo.str.extractall(r'((\w+\W+){0,3}(brasil)(\w+\W+){0,3})')
# Out:
#                                                                      0  \
# date                match
# 2017-10-10 08:48:00 0              La genial publicidad brasileña del
# 2017-10-19 13:50:00 0                      Justicia brasilera multa a
# 2017-10-24 15:37:00 0      sufrió ex seleccionado brasileño Jefferson
# 2017-10-06 14:54:00 0                impunidad a testigo brasileño de
# 2017-10-15 10:53:00 0               30 mártires brasileños asesinados
# 2017-10-26 00:50:00 0                   Diputados brasileños bloquean
# 2017-10-10 19:30:00 0                      Poropopo...": brasileños y
# 2017-10-26 12:35:00 0                       n de arquero brasileño en
# 2017-10-10 12:51:00 0                  Seleccionado brasileño Gabriel
# 2017-10-09 14:48:00 0                      guardería infantil brasileñ
# 2017-10-06 08:44:00 0                        a de los brasileños para
# 2017-09-14 11:20:00 0       ministro de agricultura brasileño acusado
# ...

# %% [markdown]
# # Transformar data (cast y melt)

# %%
data['t']=data.tagas.str.replace("#","",1).str.split("#")

# %%
df = data.tagas.str.replace("#","",1).str.split("#",expand=True).join(data[['titulo']], how='left')

# %%
(data['t'].apply(lambda x: pd.Series(x)).stack().reset_index(level=1, drop=True).to_frame('t').join(data[['titulo']], how='left'))
# Out:
#                                             t  \
# date
# 2017-09-12 09:10:00            Colegio Médico
# 2017-09-12 09:10:00         comuneros mapuche
# 2017-09-12 09:10:00               Gendarmería
# 2017-09-12 09:10:00                    Huelga
# 2017-09-12 09:10:00    Región de la Araucanía
# 2017-09-12 09:10:00                    Temuco
# 2017-09-12 09:12:00            Matías Salazar
# 2017-09-12 09:12:00                  Querella
# 2017-09-12 09:12:00      Región Metropolitana
# 2017-09-12 09:12:00                  Santiago
# 2017-09-12 09:12:00                     taxis
# 2017-09-12 09:12:00               Transportes
# 2017-09-12 09:20:00                 Accidente
# 2017-09-12 09:20:00               Carabineros
# 2017-09-12 09:20:00                  Colisión
# 2017-09-12 09:20:00                  Lactante
# 2017-09-12 09:20:00                  policial
# 2017-09-12 09:20:00              Punta Arenas
# 2017-09-12 09:20:00      Región de Magallanes
# ...

# %%
df.head()
pd.melt(df, id_vars=['titulo'], value_vars=['0'],['1'],['2'],['3'],['4'],['5'],['6'])
# Out:
#   File "<ipython-input-91-bc76c83ab05e>", line 2
#     pd.melt(df, id_vars=['titulo'], value_vars=['0'],['1'],['2'],['3'],['4'],['5'],['6'])
# SyntaxError: non-keyword arg after keyword arg

# %%
### melt like R
pd.DataFrame([tuple(list(x)+[val]) for x, val in np.ndenumerate(a)])

# %%
#data.tagas.str.split("#",expand=True)
#pd.melt(data, id_vars=['titulo'], value_vars=['t'])

# %% [markdown]
# # Unir bases de datos

# %% [markdown]
# ### Unir al lado

# %%
dataUnida = pd.concat([data.reset_index(drop=True),data2], axis=1)

# %% [markdown]
# ### Unir abajo

# %%
dataUnida = pd.concat(data,data2)

# %% [markdown]
# ### Join

# %%
pd.merge(left, right, on='key')

# %% [markdown]
# # Dividir y unir Columnas

# %%
data0 = pd.DataFrame(data.cat.str.split('/').tolist(),
                                   columns = ['noticia','Cat'])
